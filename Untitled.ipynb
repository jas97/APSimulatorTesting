# %%
from simglucose.simulation.user_interface import simulate
import gym

# %%
simulate()
# Out:
# Show animation? (y/n)  n
# Use multiple processes? (y/n)  n
# Folder name to save results [default]:  data
# Results will be saved in D:\Fax\PhD\APSimulator\results\data
# Input simulation time (hr):  24
# Select scnenario:
# [1] Random Scnenario
# [2] Custom Scnenario
# >>> 1
# Select random seed for random scenario [None]:  1
# Input simulation start time (hr):  0000
# Simulation start time is set to 2020-10-16 00:00:00.
# Select virtual patients:
# [1] All
# [2] All Adolescents
# [3] All Adults
# [4] All Children
# [5] By ID
# >>>  1
# Select the CGM sensor:
# [1] Dexcom
# [2] GuardianRT
# [3] Navigator
# >>>  1
# Select Random Seed for Sensor Noise [None]:  1
# Select the insulin pump:
# [1] Cozmo
# [2] Insulet
# >>>  1
# Select controller:
# [1] Basal-Bolus Controller
# >>> 1
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Process ID: 10336
# Simulation starts ...
# Simulation Completed!
# Simulation took 302.38324213027954 sec.
# 0

# %%
from gym.envs.registration import register

# %%
register(
    id='simglucose-adolescent2-v0',
    entry_point='simglucose.envs:T1DSimEnv',
    kwargs={'patient_name': 'adolescent#002'}
)

# %%
env = gym.make('simglucose-adolescent2-v0')
# Out:
# C:\Users\Jasmina\anaconda3\lib\site-packages\gym\envs\registration.py:17: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
observation = env.reset()
for t in range(100):
    env.render(mode='human')
#     print(observation)
    action = env.action_space.sample()
#     print(action)
    observation, reward, done, info = env.step(action)
    if done:
        print("Episode finished after {} timesteps".format(t + 1))
        break
# Out:
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in greater
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# C:\Users\Jasmina\anaconda3\lib\site-packages\simglucose\simulation\rendering.py:97: RuntimeWarning: invalid value encountered in less
#   adjust_ylim(self.axes[2], min(data['insulin']), max(data['insulin']))
# Episode finished after 18 timesteps
